# %%
import os
import numpy as np
import pandas as pd
import networkx as nx
from matplotlib import pyplot as plt

# %%
n = 50
m = 2
G = nx.barabasi_albert_graph(n, m)
nx.draw_kamada_kawai(G, node_size=50)
plt.show()

# %%
edge_G = nx.line_graph(G)

# %%
nx.draw_kamada_kawai(edge_G, node_size=50)
plt.show()
